# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('sheet.csv')
df
# Out:
#      funding  team  revenue
# 0       1.00   138     5.43
# 1       1.05   253    11.76
# 2       1.19   283    12.46
# 3       1.42     5     0.82
# 4       1.58    64     4.73
# ..       ...   ...      ...
# 495    98.67     9    19.09
# 496    98.70    76    31.98
# 497    99.01   237    45.53
# 498    99.06   183    38.63
# 499    99.30    12    31.24
#
# [500 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   funding  500 non-null    float64
#  1   team     500 non-null    int64
#  2   revenue  500 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
df.describe()
# Out:
#           funding        team     revenue
# count  500.000000  500.000000  500.000000
# mean    50.107040  149.452000   22.550680
# std     29.719711   88.272009   11.036894
# min      1.000000    2.000000    0.820000
# 25%     24.505000   76.000000   13.985000
# 50%     51.560000  146.000000   21.660000
# 75%     75.737500  227.000000   30.012500
# max     99.300000  300.000000   61.860000

# %%
import plotly.express as ex
import plotly.io as pio
pio.renderers.default = 'browser'
ex.scatter_3d(df, x='funding', y="team", z="revenue")

# %%
x = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, 249 to 102
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   funding  400 non-null    float64
#  1   team     400 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 9.4 KB

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
df.head(4)
# Out:
#    funding  team  revenue
# 0     1.00   138     5.43
# 1     1.05   253    11.76
# 2     1.19   283    12.46
# 3     1.42     5     0.82

# %%
b0 = model.intercept_
b = model.coef_
b1 = b0
y = (b[0] *1.05	) + (b[1] * 253) + b0

# %%
y
# Out:
# np.float64(13.050626345378529)

# %%
import plotly.graph_objects as go
x_values = np.linspace(
    df['funding'].min(),
    df['funding'].max(),
    10
)
y_values = np.linspace(
    df['team'].min(),
    df['team'].max(),
    10
)
xGrid, yGrid = np.meshgrid(x_values, y_values)

final = pd.DataFrame({
    'funding': xGrid.ravel(),
    'team': yGrid.ravel()
})

z_final = model.predict(final).reshape(10, 10)
fig = ex.scatter_3d(df, x='funding', y='team', z='revenue')
fig.add_trace(go.Surface(x=x_values, y=y_values, z=z_final, opacity=0.5, colorscale='Viridis'))
fig.show()

# %%
from joblib import dump

dump(model, 'model.joblib')
# Out:
# ['model.joblib']
