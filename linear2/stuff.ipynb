# %%
pip install numpy pandas matplotlib scikit-learn
# Out:
# ]4;0;#1A1B1B\]1;0;#1A1B1B\]4;1;#8383FF\]4;2;#63DEDC\]4;3;#75FCDD\]4;4;#78B4C2\]4;5;#7AAEEA\]4;6;#81D7DE\]4;7;#CCDBD5\]4;8;#B1BCB5\]4;9;#BCB9FF\]4;10;#F5FFFE\]4;11;#FFFFFF\]4;12;#BEE3E8\]4;13;#C8DAFF\]4;14;#ECFEFF\]4;15;#DDE3E5\]10;#CCDBD5\]11;[100]#1A1B1B\]12;#CCDBD5\]13;#CCDBD5\]17;#CCDBD5\]19;#1A1B1B\]4;232;#CCDBD5\]4;256;#CCDBD5\]708;[100]#1A1B1B\]11;#1A1B1B\Requirement already satisfied: numpy in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: pandas in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: matplotlib in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: scikit-learn in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('House_Rent_Dataset.csv')
df = df.dropna()

# %%
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]

# %%
plt.scatter(df['Size'], df['Rent'])

# %%
x = df.iloc[:, 3:4]
y = df["Rent"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
m = model.coef_
b = model.intercept_
print(f"Coefficient: {m}, Intercept: {b}")
# Out:
# Coefficient: [49.45643895], Intercept: -12677.58950320886

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
plt.scatter(x_train, y_train, color='blue', label='Training Data')
plt.scatter(x_test, y_test, color='green', label='Testing Data')
plt.plot(x_test, y_pred, color='red', label='Regression Line')
plt.xlabel('Size')
plt.ylabel('Rent')
plt.title('House Rent Prediction')
plt.legend()
plt.show()

# %%
pip install joblib #type: ignore
# Out:
# ]4;0;#1A1B1B\]1;0;#1A1B1B\]4;1;#8383FF\]4;2;#63DEDC\]4;3;#75FCDD\]4;4;#78B4C2\]4;5;#7AAEEA\]4;6;#81D7DE\]4;7;#CCDBD5\]4;8;#B1BCB5\]4;9;#BCB9FF\]4;10;#F5FFFE\]4;11;#FFFFFF\]4;12;#BEE3E8\]4;13;#C8DAFF\]4;14;#ECFEFF\]4;15;#DDE3E5\]10;#CCDBD5\]11;[100]#1A1B1B\]12;#CCDBD5\]13;#CCDBD5\]17;#CCDBD5\]19;#1A1B1B\]4;232;#CCDBD5\]4;256;#CCDBD5\]708;[100]#1A1B1B\]11;#1A1B1B\Requirement already satisfied: joblib in /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
joblib.dump(model, 'linear_regression_model.joblib')
# Out:
# ['linear_regression_model.joblib']

# %%
# Out:
# array([29360.38360592])
