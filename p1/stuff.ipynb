# %%
pip install numpy pandas matplotlib scikit-learn #type: ignore
# Out:
# ]4;0;#1A1B1B\]1;0;#1A1B1B\]4;1;#8383FF\]4;2;#63DEDC\]4;3;#75FCDD\]4;4;#78B4C2\]4;5;#7AAEEA\]4;6;#81D7DE\]4;7;#CCDBD5\]4;8;#B1BCB5\]4;9;#BCB9FF\]4;10;#F5FFFE\]4;11;#FFFFFF\]4;12;#BEE3E8\]4;13;#C8DAFF\]4;14;#ECFEFF\]4;15;#DDE3E5\]10;#CCDBD5\]11;[100]#1A1B1B\]12;#CCDBD5\]13;#CCDBD5\]17;#CCDBD5\]19;#1A1B1B\]4;232;#CCDBD5\]4;256;#CCDBD5\]708;[100]#1A1B1B\]11;#1A1B1B\Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.3.1)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("book_read.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   HoursSpentReading  300 non-null    float64
#  1   BooksRead          300 non-null    float64
# dtypes: float64(2)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#        HoursSpentReading   BooksRead
# count         300.000000  300.000000
# mean           10.000000    2.499847
# std             5.802459    1.473970
# min             0.000000    0.000000
# 25%             5.000000    1.287311
# 50%            10.000000    2.554748
# 75%            15.000000    3.738741
# max            20.000000    5.175771

# %%
df
# Out:
#      HoursSpentReading  BooksRead
# 0             0.000000   0.099343
# 1             0.066890   0.000000
# 2             0.133779   0.162983
# 3             0.200669   0.354773
# 4             0.267559   0.020059
# ..                 ...        ...
# 295          19.732441   4.794528
# 296          19.799331   5.129753
# 297          19.866221   5.028015
# 298          19.933110   5.145850
# 299          20.000000   5.125926
#
# [300 rows x 2 columns]

# %%
plt.scatter(df['HoursSpentReading'], df['BooksRead'], color='blue')

# %%
x=df.iloc[:,0:1]
y=df["BooksRead"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
m = model.coef_
b = model.intercept_
print(f"Model: y = {m[0]} * x + {b}")
# Out:
# Model: y = 0.25168315102404026 * x + -0.02250172463794131

# %%
df.head()
# Out:
#    HoursSpentReading  BooksRead
# 0           0.000000   0.099343
# 1           0.066890   0.000000
# 2           0.133779   0.162983
# 3           0.200669   0.354773
# 4           0.267559   0.020059

# %%
plt.scatter(x_train, y_train, color='blue', label='Training Data')
plt.scatter(x_test, y_test, color='green', label='Test Data')
plt.plot(x_test, y_pred, color='red', label='Regression Line')

# %%
pip install joblib #type: ignore
# Out:
# ]4;0;#1A1B1B\]1;0;#1A1B1B\]4;1;#8383FF\]4;2;#63DEDC\]4;3;#75FCDD\]4;4;#78B4C2\]4;5;#7AAEEA\]4;6;#81D7DE\]4;7;#CCDBD5\]4;8;#B1BCB5\]4;9;#BCB9FF\]4;10;#F5FFFE\]4;11;#FFFFFF\]4;12;#BEE3E8\]4;13;#C8DAFF\]4;14;#ECFEFF\]4;15;#DDE3E5\]10;#CCDBD5\]11;[100]#1A1B1B\]12;#CCDBD5\]13;#CCDBD5\]17;#CCDBD5\]19;#1A1B1B\]4;232;#CCDBD5\]4;256;#CCDBD5\]708;[100]#1A1B1B\]11;#1A1B1B\Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
joblib.dump(model, 'linear_regression_model.joblib')
# Out:
# ['linear_regression_model.joblib']

# %%
file = joblib.load('linear_regression_model.joblib')
file.predict([[5]])
# Out:
# /home/mannu/Documents/jupyter-stuff/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.23591403])
